# %%
print("all_ok")
# Out:
# all_ok

# %%
from langchain_groq import ChatGroq

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="qwen/qwen3-32b")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
embedding_model.embed_query("what is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\langchain_google_genai\embeddings.py:497, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     496 try:
# --> 497     result = self.client.models.embed_content(
#     498         model=self.model,
#     499         contents=text,
#     500         config=config,
#     501     )
#     502 except ClientError as e:
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\models.py:6125, in Models.embed_content(self, model, contents, config)
#    6124     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6125   return self._embed_content(model=model, contents=contents, config=config)
#    6127 if t.t_is_vertex_embed_content_model(model):
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\models.py:4936, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    4934 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4936 response = self._api_client.request(
#    4937     'post', path, request_dict, http_options
#    4938 )
#    4940 response_dict = {} if not response.body else json.loads(response.body)
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\_api_client.py:1750, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1747 http_request = self._build_request(
#    1748     http_method, path, request_dict, http_options
#    1749 )
# -> 1750 response = self._request(http_request, http_options, stream=False)
#    1751 response_body = (
#    1752     response.response_stream[0] if response.response_stream else ''
#    1753 )
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\_api_client.py:1537, in BaseApiClient._request(self, http_request, http_options, stream)
#    1535     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1537 return self._retry(self._request_once, http_request, stream)
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\_api_client.py:1514, in BaseApiClient._request_once(self, http_request, stream)
#    1513   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1514 errors.APIError.raise_for_response(response)
#    1515 return HttpResponse(
#    1516     response.headers, response if stream else [response.text]
#    1517 )
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\google\genai\errors.py:202, in APIError.raise_error(cls, status_code, response_json, response)
#     201 if 400 <= status_code < 500:
# --> 202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 embedding_model.embed_query("what is the capital of France?")
#
# File d:\Code_Programming\AIML\GitRepo\DocumentAnalysis_RAG\env\lib\site-packages\langchain_google_genai\embeddings.py:504, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     502 except ClientError as e:
#     503     msg = f"Error embedding content ({e.status}): {e}"
# --> 504     raise GoogleGenerativeAIError(msg) from e
#     505 except Exception as e:
#     506     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/embedding-001 is not found for API version v1beta, or is not supported for embedContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
